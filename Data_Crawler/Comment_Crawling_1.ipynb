# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

import re
import pandas as pd
import xlrd

# %%
result_1 = pd.read_excel('2020.01.01-2020.01.31_result.xlsx')

# %%
result_1.head()
# Out:
#    Unnamed: 0        years      company  \
# 0           0  2020.01.16.     OhmyNews
# 1           1  2020.01.13.    donga.com
# 2           2  2020.01.07.         JTBC
# 3           3  2020.01.11.         연합뉴스
# 4           4  2020.01.02.  SBS & SBSi
#
#                                      title  \
# 0  '당색 거리두기' 나선 한국당...김용균법 시행일에 '공익신고자' 영입
# 1    “美 없이 전쟁할 능력 갖춰야”… 미국과 거리두기 나선 영국, 왜?
# 2        [비하인드+] 추미애-윤석열, 거리두기? '어색한 첫 만남'
# 3        홍콩처럼 '中거리두기' 택한 대만인들…시진핑 '중국몽' 상처
# 4          이라크 반정부시위대, 美 대사관 반미 시위대와 거리 두기
#
#                                             contents  \
# 0  한국당 인재 4호...산업재해 은폐한 회사 내부 고발한 이종헌씨[오마이뉴스 글:류승...
# 1  벤 월리스 영국 국방장관. 사진=뉴시스“미국 없이 미래의 전쟁에 대비해야 한다.” ...
# 2  동영상 뉴스     [앵커]취재기자에게 직접 취재의 뒷 얘기를 듣는 '비하인드 플러...
# 3  투표로 '반중 정서' 분출…'주권 수호' 차이잉원 다시 선택中 일국양제 압박 역효과...
# 4  이라크 반정부 시위대가 최근 이틀간 바그다드 주재 미국 대사관에서 벌어진 반미 시위...
#
#                                                 link
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
del result_1['Unnamed: 0']

# %%
result_1.head()
# Out:
#          years      company                                    title  \
# 0  2020.01.16.     OhmyNews  '당색 거리두기' 나선 한국당...김용균법 시행일에 '공익신고자' 영입
# 1  2020.01.13.    donga.com    “美 없이 전쟁할 능력 갖춰야”… 미국과 거리두기 나선 영국, 왜?
# 2  2020.01.07.         JTBC        [비하인드+] 추미애-윤석열, 거리두기? '어색한 첫 만남'
# 3  2020.01.11.         연합뉴스        홍콩처럼 '中거리두기' 택한 대만인들…시진핑 '중국몽' 상처
# 4  2020.01.02.  SBS & SBSi           이라크 반정부시위대, 美 대사관 반미 시위대와 거리 두기
#
#                                             contents  \
# 0  한국당 인재 4호...산업재해 은폐한 회사 내부 고발한 이종헌씨[오마이뉴스 글:류승...
# 1  벤 월리스 영국 국방장관. 사진=뉴시스“미국 없이 미래의 전쟁에 대비해야 한다.” ...
# 2  동영상 뉴스     [앵커]취재기자에게 직접 취재의 뒷 얘기를 듣는 '비하인드 플러...
# 3  투표로 '반중 정서' 분출…'주권 수호' 차이잉원 다시 선택中 일국양제 압박 역효과...
# 4  이라크 반정부 시위대가 최근 이틀간 바그다드 주재 미국 대사관에서 벌어진 반미 시위...
#
#                                                 link
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...

# %%
url="https://news.naver.com/main/ranking/read.nhn?mid=etc&sid1=111&rankingType=popular_day&oid=018&aid=0004300484&date=20190128&type=1&rankingSeq=5&rankingSectionId=101"    # api 이용 위해, 기사 하나 가져오기

header = {
    "User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36", 
    "referer": url,  
}

# %%
# link url 리스트
url = []
for l in result_1['link']:    
    url.append(l)

# link url 파싱
oid = result_1['link'].apply(lambda x: x.split("oid=")[1].split("&")[0]) 
aid = result_1['link'].apply(lambda x: x.split("aid=")[1])
        
# result_path
RESULT_PATH = '/home/jeehyun.lee.conda/'

# %%
c_List=[] 
d_List=[]

def contents_flat(c_List,d_List): 
    flatList = [] 
    d_flatList=[]
   
    for elem in c_List: 
        # if an element of a list is a list 
        # iterate over this list and add elements to flatList  
        
        # elem=re.sub('"',' ',str(elem))
        if type(elem) == list: 
            for e in elem: 
                flatList.append(e) 
        else: 
            flatList.append(elem) 
           
    for elem in d_List: 
        if type(elem) == list: 
            for e in elem: 
                e=re.sub('\\+0900',' ',e)
                d_flatList.append(e) 
        else: 
            elem=re.sub('\\+0900',' ',elem)
            d_flatList.append(elem) 

    # f.write(str(flatList))
    excel_make(flatList,d_flatList)
             
def excel_make(flatList,d_flatList): 
    result= {"comments":flatList, "date":d_flatList}
    df = pd.DataFrame(result)  # df로 변환
    df.to_excel(RESULT_PATH+"comments_result_1.xlsx",sheet_name='sheet1')

def main():
    for o,a in [(oid, aid)]:
        for i in range(len(url)):
            page = 1
            comment_url = "https://apis.naver.com/commentBox/cbox/web_neo_list_jsonp.json?ticket=news&templateId=default_society&pool=cbox5&_callback=jQuery1707138182064460843_1523512042464&lang=ko&country=&objectId=news"+o[i]+"%2C"+a[i]+"&categoryId=&pageSize=20&indexSize=10&groupId=&listType=OBJECT&pageType=more&page="+str(page)+"&refresh=false&sort=FAVORITE"
            r=requests.get(comment_url,headers=header)
            cont=bs(r.content,"html.parser")     
            total_comm=str(cont).split('comment":')[1].split(",")[0]
                
            match=re.findall('"contents":"([^\*]*)","userIdNo"', str(cont))   #소괄호 안에 있는것을 크롤링해온다.
            date=re.findall('"modTime":"([^\*]*)","modTimeGmt"', str(cont))

            c_List.append(match)
            d_List.append(date)
            
            while True:
                if int(total_comm) <= ((page) * 20): 
                    break
                else:
                    page += 1
    
    contents_flat(c_List,d_List)  
    
main()
